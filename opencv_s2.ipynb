# %% [markdown]
# <a href="https://colab.research.google.com/github/tussh7patil/open_cv/blob/main/opencv_s2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# step-1 install req packages
#
# package name: opencv-python

# %%
pip install opencv-python

# %% [markdown]
# step-2 import packages

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# step-3 read and show the image
#
# in order to read the image

# %%
dir(cv2)
# Out:
# ['ACCESS_FAST',
#  'ACCESS_MASK',
#  'ACCESS_READ',
#  'ACCESS_RW',
#  'ACCESS_WRITE',
#  'ADAPTIVE_THRESH_GAUSSIAN_C',
#  'ADAPTIVE_THRESH_MEAN_C',
#  'AGAST_FEATURE_DETECTOR_AGAST_5_8',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12D',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12S',
#  'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION',
#  'AGAST_FEATURE_DETECTOR_OAST_9_16',
#  'AGAST_FEATURE_DETECTOR_THRESHOLD',
#  'AKAZE',
#  'AKAZE_DESCRIPTOR_KAZE',
#  'AKAZE_DESCRIPTOR_KAZE_UPRIGHT',
#  'AKAZE_DESCRIPTOR_MLDB',
#  'AKAZE_DESCRIPTOR_MLDB_UPRIGHT',
#  'AKAZE_create',
#  'ALGO_HINT_ACCURATE',
#  'ALGO_HINT_APPROX',
#  'ALGO_HINT_DEFAULT',
#  'AffineFeature',
#  'AffineFeature_create',
#  'AffineTransformer',
#  'AgastFeatureDetector',
#  'AgastFeatureDetector_AGAST_5_8',
#  'AgastFeatureDetector_AGAST_7_12d',
#  'AgastFeatureDetector_AGAST_7_12s',
#  'AgastFeatureDetector_NONMAX_SUPPRESSION',
#  'AgastFeatureDetector_OAST_9_16',
#  'AgastFeatureDetector_THRESHOLD',
#  'AgastFeatureDetector_create',
# ...

# %%
image = cv2.imread('/content/kids.jpeg')

# %%
cv2_imshow(image) #to show image
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
image.shape
#hight = 183
# width = 275
# channel = 3 img BGR
# Out:
# (183, 275, 3)

# %% [markdown]
# **convert into gray scale**
#
# cv2.imread -- read img
#
# cv2_imshow -- showing img
#
# i want convert one img to another
#
# cv2.cvtColor
#   - do i need original img
#   - do i need mension which color

# %%
from google.colab.patches import cv2_imshow
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
from google.colab.patches import cv2_imshow
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2_imshow(rgb_image)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
from google.colab.patches import cv2_imshow
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2_imshow(hsv_image)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %% [markdown]
# img -- bgr
#
# gray img -- black and white
#
# rgb img --RGB
#
# hsv img -- thresholding

# %% [markdown]
# **Resized Image**

# %%
image.shape
# Out:
# (183, 275, 3)

# %%
from google.colab.patches import cv2_imshow
resized_image = cv2.resize(image, (200,200))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
resized_image.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# **Cropping**
#
# - cropping -- selecting perticular part
# - image means pixel number
#
# - eg. imge 767, 1366
# - hight range 0 to 767
# - width range 0 to 1366
#
# - height:[50:200] width[50:200]

# %%
crop_img = image[50:200, 50:200]
cv2_imshow(crop_img)
# Out:
# <PIL.Image.Image image mode=RGB size=150x133>

# %% [markdown]
# **Flip the image**

# %%
flip_v = cv2.flip(image, 0)
cv2_imshow(flip_v)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
flip_v = cv2.flip(image, 0)
flip_h = cv2.flip(image, 1)
flip_hv = cv2.flip(image, -1)

cv2_imshow(flip_v)
cv2_imshow(flip_h)
cv2_imshow(flip_hv)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
