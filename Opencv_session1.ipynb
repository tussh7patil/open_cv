# %% [markdown]
# <a href="https://colab.research.google.com/github/tussh7patil/open_cv/blob/main/Opencv_session1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## install the packages

# %%
# !pip install opencv-python

# %% [markdown]
# ## import packages

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## load the image or read the image

# %%
image_cv = cv2.imread("/content/person.jpg")
cv2_imshow(image_cv)
# Out:
# <PIL.Image.Image image mode=RGB size=640x424>

# %%
image_cv.shape
# img is kind of matrix
# row - 424
# colom - 640
# 3 - indicate RGB channel
# Out:
# (424, 640, 3)

# %%
image_cv
#[241, 203, 191]
# in cv consider color not rgb - bgr
# 241 - b
# 203 - g
# 191 - r
# Out:
# array([[[241, 203, 191],
#         [241, 203, 191],
#         [240, 202, 190],
#         ...,
#         [248, 208, 190],
#         [248, 208, 190],
#         [249, 209, 191]],
#
#        [[240, 202, 190],
#         [240, 202, 190],
#         [240, 202, 190],
#         ...,
#         [248, 208, 190],
#         [248, 208, 190],
#         [248, 208, 190]],
#
#        [[239, 201, 189],
#         [239, 201, 189],
#         [239, 201, 189],
#         ...,
#         [247, 207, 189],
#         [247, 207, 189],
#         [248, 208, 190]],
#
#        ...,
#
#        [[137, 169, 192],
#         [118, 150, 173],
#         [120, 154, 177],
#         ...,
#         [107, 132, 152],
#         [123, 148, 168],
#         [ 81, 106, 126]],
#
#        [[121, 155, 178],
#         [136, 171, 191],
#         [132, 167, 187],
#         ...,
#         [ 92, 117, 137],
#         [105, 130, 150],
#         [105, 130, 150]],
#
#        [[126, 160, 183],
#         [124, 159, 179],
#         [121, 156, 176],
# ...

# %%
b,g,r = cv2.split(image_cv)

# %%
b.shape
# Out:
# (424, 640)

# %%
g
# Out:
# array([[203, 203, 202, ..., 208, 208, 209],
#        [202, 202, 202, ..., 208, 208, 208],
#        [201, 201, 201, ..., 207, 207, 208],
#        ...,
#        [169, 150, 154, ..., 132, 148, 106],
#        [155, 171, 167, ..., 117, 130, 130],
#        [160, 159, 156, ..., 138, 154, 145]], dtype=uint8)

# %%
r
# Out:
# array([[191, 191, 190, ..., 190, 190, 191],
#        [190, 190, 190, ..., 190, 190, 190],
#        [189, 189, 189, ..., 189, 189, 190],
#        ...,
#        [192, 173, 177, ..., 152, 168, 126],
#        [178, 191, 187, ..., 137, 150, 150],
#        [183, 179, 176, ..., 158, 174, 165]], dtype=uint8)

# %%
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=640x424>

# %%
cv2_imshow(g)
# Out:
# <PIL.Image.Image image mode=L size=640x424>

# %%
cv2_imshow(r)
# Out:
# <PIL.Image.Image image mode=L size=640x424>

# %%
import matplotlib.pyplot as plt
# all pic are black and white
# thatswhy we use other package help

# %%
plt.imshow(r, cmap='Reds')

# %%
plt.imshow(r, cmap='Greens')

# %% [markdown]
# ## cv2.imshow ---- in jupyter notebook
# ## cv2_imshow ---- in colab
